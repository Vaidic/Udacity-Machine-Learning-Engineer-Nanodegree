# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/100
#  - 34s - loss: 1.6751 - acc: 0.3920 - val_loss: 1.3836 - val_acc: 0.5002
#
# Epoch 00001: val_loss improved from inf to 1.38355, saving model to aug_model.weights.best.hdf5
# Epoch 2/100
#  - 34s - loss: 1.3838 - acc: 0.5041 - val_loss: 1.2605 - val_acc: 0.5453
#
# Epoch 00002: val_loss improved from 1.38355 to 1.26046, saving model to aug_model.weights.best.hdf5
# Epoch 3/100
#  - 33s - loss: 1.2873 - acc: 0.5399 - val_loss: 1.1536 - val_acc: 0.5901
#
# Epoch 00003: val_loss improved from 1.26046 to 1.15359, saving model to aug_model.weights.best.hdf5
# Epoch 4/100
#  - 33s - loss: 1.2309 - acc: 0.5660 - val_loss: 1.1726 - val_acc: 0.5747
#
# Epoch 00004: val_loss did not improve from 1.15359
# Epoch 5/100
#  - 33s - loss: 1.1960 - acc: 0.5815 - val_loss: 1.0761 - val_acc: 0.6222
#
# Epoch 00005: val_loss improved from 1.15359 to 1.07611, saving model to aug_model.weights.best.hdf5
# Epoch 6/100
#  - 33s - loss: 1.1705 - acc: 0.5914 - val_loss: 1.0982 - val_acc: 0.6184
#
# Epoch 00006: val_loss did not improve from 1.07611
# Epoch 7/100
#  - 33s - loss: 1.1574 - acc: 0.5968 - val_loss: 1.0013 - val_acc: 0.6544
#
# Epoch 00007: val_loss improved from 1.07611 to 1.00131, saving model to aug_model.weights.best.hdf5
# Epoch 8/100
#  - 33s - loss: 1.1476 - acc: 0.6031 - val_loss: 1.0362 - val_acc: 0.6490
#
# Epoch 00008: val_loss did not improve from 1.00131
# Epoch 9/100
#  - 33s - loss: 1.1566 - acc: 0.6035 - val_loss: 1.0476 - val_acc: 0.6500
#
# Epoch 00009: val_loss did not improve from 1.00131
# Epoch 10/100
#  - 33s - loss: 1.1566 - acc: 0.6038 - val_loss: 1.0070 - val_acc: 0.6544
#
# Epoch 00010: val_loss did not improve from 1.00131
# Epoch 11/100
#  - 32s - loss: 1.1703 - acc: 0.5995 - val_loss: 1.0350 - val_acc: 0.6498
#
# Epoch 00011: val_loss did not improve from 1.00131
# Epoch 12/100
#  - 33s - loss: 1.1733 - acc: 0.6028 - val_loss: 0.9708 - val_acc: 0.6629
#
# Epoch 00012: val_loss improved from 1.00131 to 0.97078, saving model to aug_model.weights.best.hdf5
# Epoch 13/100
#  - 33s - loss: 1.1833 - acc: 0.5989 - val_loss: 1.1251 - val_acc: 0.6130
#
# Epoch 00013: val_loss did not improve from 0.97078
# Epoch 14/100
#  - 33s - loss: 1.2033 - acc: 0.5950 - val_loss: 1.0234 - val_acc: 0.6516
#
# Epoch 00014: val_loss did not improve from 0.97078
# Epoch 15/100
#  - 33s - loss: 1.2088 - acc: 0.5907 - val_loss: 1.1101 - val_acc: 0.6356
#
# Epoch 00015: val_loss did not improve from 0.97078
# Epoch 16/100
#  - 33s - loss: 1.2262 - acc: 0.5859 - val_loss: 1.0609 - val_acc: 0.6544
#
# Epoch 00016: val_loss did not improve from 0.97078
# Epoch 17/100
#  - 33s - loss: 1.2418 - acc: 0.5828 - val_loss: 1.0529 - val_acc: 0.6428
#
# Epoch 00017: val_loss did not improve from 0.97078
# Epoch 18/100
#  - 33s - loss: 1.2612 - acc: 0.5755 - val_loss: 1.0293 - val_acc: 0.6571
#
# Epoch 00018: val_loss did not improve from 0.97078
# Epoch 19/100
#  - 33s - loss: 1.2697 - acc: 0.5708 - val_loss: 1.0888 - val_acc: 0.6262
#
# Epoch 00019: val_loss did not improve from 0.97078
# Epoch 20/100
#  - 33s - loss: 1.3039 - acc: 0.5641 - val_loss: 1.1285 - val_acc: 0.6116
#
# Epoch 00020: val_loss did not improve from 0.97078
# Epoch 21/100
#  - 33s - loss: 1.3156 - acc: 0.5570 - val_loss: 1.2293 - val_acc: 0.5885
#
# Epoch 00021: val_loss did not improve from 0.97078
# Epoch 22/100
#  - 32s - loss: 1.3346 - acc: 0.5506 - val_loss: 1.2621 - val_acc: 0.5705
#
# Epoch 00022: val_loss did not improve from 0.97078
# Epoch 23/100
#  - 33s - loss: 1.3630 - acc: 0.5424 - val_loss: 1.1402 - val_acc: 0.6212
#
# Epoch 00023: val_loss did not improve from 0.97078
# Epoch 24/100
#  - 32s - loss: 1.3775 - acc: 0.5405 - val_loss: 1.1340 - val_acc: 0.6010
#
# Epoch 00024: val_loss did not improve from 0.97078
# Epoch 25/100
#  - 33s - loss: 1.4103 - acc: 0.5287 - val_loss: 1.1775 - val_acc: 0.6002
#
# Epoch 00025: val_loss did not improve from 0.97078
# Epoch 26/100
#  - 32s - loss: 1.4044 - acc: 0.5268 - val_loss: 1.2024 - val_acc: 0.5897
#
# Epoch 00026: val_loss did not improve from 0.97078
# Epoch 27/100
#  - 33s - loss: 1.4239 - acc: 0.5196 - val_loss: 1.2459 - val_acc: 0.5755
#
# Epoch 00027: val_loss did not improve from 0.97078
# Epoch 28/100
#  - 32s - loss: 1.4282 - acc: 0.5193 - val_loss: 1.2758 - val_acc: 0.5541
#
# Epoch 00028: val_loss did not improve from 0.97078
# Epoch 29/100
#  - 33s - loss: 1.4440 - acc: 0.5135 - val_loss: 1.2466 - val_acc: 0.5717
#
# Epoch 00029: val_loss did not improve from 0.97078
# Epoch 30/100
#  - 33s - loss: 1.4585 - acc: 0.5080 - val_loss: 1.1792 - val_acc: 0.6014
#
# Epoch 00030: val_loss did not improve from 0.97078
# Epoch 31/100
#  - 33s - loss: 1.4749 - acc: 0.5058 - val_loss: 1.2555 - val_acc: 0.5727
#
# Epoch 00031: val_loss did not improve from 0.97078
# Epoch 32/100
#  - 33s - loss: 1.4902 - acc: 0.4986 - val_loss: 1.3176 - val_acc: 0.5473
#
# Epoch 00032: val_loss did not improve from 0.97078
# Epoch 33/100
#  - 33s - loss: 1.5189 - acc: 0.4904 - val_loss: 1.2778 - val_acc: 0.5561
#
# Epoch 00033: val_loss did not improve from 0.97078
# Epoch 34/100
#  - 32s - loss: 1.5477 - acc: 0.4812 - val_loss: 1.3088 - val_acc: 0.5391
#
# Epoch 00034: val_loss did not improve from 0.97078
# Epoch 35/100
#  - 33s - loss: 1.5566 - acc: 0.4755 - val_loss: 1.5156 - val_acc: 0.4978
#
# Epoch 00035: val_loss did not improve from 0.97078
# Epoch 36/100
#  - 33s - loss: 1.5817 - acc: 0.4665 - val_loss: 1.4200 - val_acc: 0.5106
#
# Epoch 00036: val_loss did not improve from 0.97078
# Epoch 37/100
#  - 33s - loss: 1.6022 - acc: 0.4605 - val_loss: 1.5641 - val_acc: 0.4175
#
# Epoch 00037: val_loss did not improve from 0.97078
# Epoch 38/100
#  - 33s - loss: 1.6068 - acc: 0.4514 - val_loss: 1.3557 - val_acc: 0.5224
#
# Epoch 00038: val_loss did not improve from 0.97078
# Epoch 39/100
#  - 32s - loss: 1.6049 - acc: 0.4534 - val_loss: 1.3327 - val_acc: 0.5459
#
# Epoch 00039: val_loss did not improve from 0.97078
# Epoch 40/100
#  - 33s - loss: 1.6236 - acc: 0.4548 - val_loss: 1.4674 - val_acc: 0.4810
#
# Epoch 00040: val_loss did not improve from 0.97078
# Epoch 41/100
#  - 32s - loss: 1.6333 - acc: 0.4431 - val_loss: 1.5077 - val_acc: 0.4720
#
# Epoch 00041: val_loss did not improve from 0.97078
# Epoch 42/100
#  - 32s - loss: 1.6501 - acc: 0.4382 - val_loss: 1.5479 - val_acc: 0.4716
#
# Epoch 00042: val_loss did not improve from 0.97078
# Epoch 43/100
#  - 33s - loss: 1.6625 - acc: 0.4351 - val_loss: 1.4240 - val_acc: 0.5286
#
# Epoch 00043: val_loss did not improve from 0.97078
# Epoch 44/100
#  - 32s - loss: 1.6730 - acc: 0.4298 - val_loss: 1.5363 - val_acc: 0.4619
#
# Epoch 00044: val_loss did not improve from 0.97078
# Epoch 45/100
#  - 33s - loss: 1.6782 - acc: 0.4247 - val_loss: 1.4166 - val_acc: 0.4900
#
# Epoch 00045: val_loss did not improve from 0.97078
# Epoch 46/100
#  - 33s - loss: 1.6923 - acc: 0.4259 - val_loss: 1.4225 - val_acc: 0.5116
#
# Epoch 00046: val_loss did not improve from 0.97078
# Epoch 47/100
#  - 33s - loss: 1.7008 - acc: 0.4171 - val_loss: 1.3623 - val_acc: 0.5242
#
# Epoch 00047: val_loss did not improve from 0.97078
# Epoch 48/100
#  - 33s - loss: 1.7160 - acc: 0.4124 - val_loss: 1.5437 - val_acc: 0.4369
#
# Epoch 00048: val_loss did not improve from 0.97078
# Epoch 49/100
#  - 33s - loss: 1.7191 - acc: 0.4099 - val_loss: 1.4466 - val_acc: 0.4962
#
# Epoch 00049: val_loss did not improve from 0.97078
# Epoch 50/100
#  - 33s - loss: 1.7060 - acc: 0.4118 - val_loss: 1.5201 - val_acc: 0.4533
#
# Epoch 00050: val_loss did not improve from 0.97078
# Epoch 51/100
#  - 33s - loss: 1.7202 - acc: 0.4062 - val_loss: 1.4965 - val_acc: 0.4742
#
# Epoch 00051: val_loss did not improve from 0.97078
# Epoch 52/100
#  - 32s - loss: 1.7299 - acc: 0.4007 - val_loss: 1.4585 - val_acc: 0.4718
#
# Epoch 00052: val_loss did not improve from 0.97078
# Epoch 53/100
#  - 33s - loss: 1.7438 - acc: 0.3988 - val_loss: 1.4987 - val_acc: 0.4868
#
# Epoch 00053: val_loss did not improve from 0.97078
# Epoch 54/100
#  - 33s - loss: 1.7452 - acc: 0.3969 - val_loss: 1.4648 - val_acc: 0.4806
#
# Epoch 00054: val_loss did not improve from 0.97078
# Epoch 55/100
#  - 33s - loss: 1.7507 - acc: 0.3939 - val_loss: 1.5265 - val_acc: 0.4756
#
# Epoch 00055: val_loss did not improve from 0.97078
# Epoch 56/100
#  - 33s - loss: 1.7651 - acc: 0.3854 - val_loss: 1.6046 - val_acc: 0.3968
#
# Epoch 00056: val_loss did not improve from 0.97078
# Epoch 57/100
#  - 33s - loss: 1.7747 - acc: 0.3820 - val_loss: 1.6018 - val_acc: 0.4429
#
# Epoch 00057: val_loss did not improve from 0.97078
# Epoch 58/100
#  - 33s - loss: 1.7788 - acc: 0.3765 - val_loss: 1.5476 - val_acc: 0.4501
# Epoch 00058: val_loss did not improve from 0.97078
# Epoch 59/100
#  - 33s - loss: 1.8027 - acc: 0.3718 - val_loss: 1.5679 - val_acc: 0.4415
#
# Epoch 00059: val_loss did not improve from 0.97078
# Epoch 60/100
#  - 33s - loss: 1.7994 - acc: 0.3712 - val_loss: 1.5164 - val_acc: 0.4409
#
# Epoch 00060: val_loss did not improve from 0.97078
# Epoch 61/100
#  - 33s - loss: 1.8206 - acc: 0.3606 - val_loss: 1.5305 - val_acc: 0.4543
#
# Epoch 00061: val_loss did not improve from 0.97078
# Epoch 62/100
#  - 32s - loss: 1.8079 - acc: 0.3653 - val_loss: 1.5790 - val_acc: 0.4283
#
# Epoch 00062: val_loss did not improve from 0.97078
# Epoch 63/100
#  - 33s - loss: 1.8131 - acc: 0.3668 - val_loss: 1.5322 - val_acc: 0.4583
#
# Epoch 00063: val_loss did not improve from 0.97078
# Epoch 64/100
#  - 33s - loss: 1.8200 - acc: 0.3544 - val_loss: 1.5840 - val_acc: 0.4347
#
# Epoch 00064: val_loss did not improve from 0.97078
# Epoch 65/100
#  - 32s - loss: 1.8285 - acc: 0.3563 - val_loss: 1.6414 - val_acc: 0.4193
#
# Epoch 00065: val_loss did not improve from 0.97078
# Epoch 66/100
#  - 33s - loss: 1.8249 - acc: 0.3545 - val_loss: 1.6217 - val_acc: 0.4095
#
# Epoch 00066: val_loss did not improve from 0.97078
# Epoch 67/100
#  - 32s - loss: 1.8274 - acc: 0.3525 - val_loss: 1.5947 - val_acc: 0.4251
#
# Epoch 00067: val_loss did not improve from 0.97078
# Epoch 68/100
#  - 33s - loss: 1.8239 - acc: 0.3522 - val_loss: 1.6020 - val_acc: 0.4205
#
# Epoch 00068: val_loss did not improve from 0.97078
# Epoch 69/100
#  - 33s - loss: 1.8080 - acc: 0.3560 - val_loss: 1.5758 - val_acc: 0.4401
#
# Epoch 00069: val_loss did not improve from 0.97078
# Epoch 70/100
#  - 33s - loss: 1.8268 - acc: 0.3492 - val_loss: 1.7133 - val_acc: 0.3648
#
# Epoch 00070: val_loss did not improve from 0.97078
# Epoch 71/100
#  - 33s - loss: 1.8262 - acc: 0.3441 - val_loss: 1.6055 - val_acc: 0.4291
#
# Epoch 00071: val_loss did not improve from 0.97078
# Epoch 72/100
#  - 32s - loss: 1.8473 - acc: 0.3425 - val_loss: 1.5969 - val_acc: 0.4315
#
# Epoch 00072: val_loss did not improve from 0.97078
# Epoch 73/100
#  - 33s - loss: 1.8475 - acc: 0.3372 - val_loss: 1.8098 - val_acc: 0.3730
#
# Epoch 00073: val_loss did not improve from 0.97078
# Epoch 74/100
#  - 33s - loss: 1.8348 - acc: 0.3426 - val_loss: 1.6007 - val_acc: 0.4197
#
# Epoch 00074: val_loss did not improve from 0.97078
# Epoch 75/100
#  - 32s - loss: 1.8337 - acc: 0.3404 - val_loss: 1.7262 - val_acc: 0.3828
#
# Epoch 00075: val_loss did not improve from 0.97078
# Epoch 76/100
#  - 32s - loss: 1.8417 - acc: 0.3399 - val_loss: 1.6582 - val_acc: 0.3860
#
# Epoch 00076: val_loss did not improve from 0.97078
# Epoch 77/100
#  - 33s - loss: 1.8324 - acc: 0.3392 - val_loss: 1.6990 - val_acc: 0.4024
#
# Epoch 00077: val_loss did not improve from 0.97078
# Epoch 78/100
#  - 32s - loss: 1.8449 - acc: 0.3351 - val_loss: 1.7614 - val_acc: 0.3926
#
# Epoch 00078: val_loss did not improve from 0.97078
# Epoch 79/100
#  - 33s - loss: 1.8533 - acc: 0.3340 - val_loss: 1.7966 - val_acc: 0.3862
#
# Epoch 00079: val_loss did not improve from 0.97078
# Epoch 80/100
#  - 33s - loss: 1.8334 - acc: 0.3382 - val_loss: 1.6732 - val_acc: 0.3944
#
# Epoch 00080: val_loss did not improve from 0.97078
# Epoch 81/100
#  - 33s - loss: 1.8486 - acc: 0.3359 - val_loss: 1.9839 - val_acc: 0.3446
#
# Epoch 00081: val_loss did not improve from 0.97078
# Epoch 82/100
#  - 33s - loss: 1.8464 - acc: 0.3299 - val_loss: 1.6533 - val_acc: 0.3774
#
# Epoch 00082: val_loss did not improve from 0.97078
# Epoch 83/100
#  - 33s - loss: 1.8544 - acc: 0.3259 - val_loss: 1.6751 - val_acc: 0.3970
#
# Epoch 00083: val_loss did not improve from 0.97078
# Epoch 84/100
#  - 32s - loss: 1.8561 - acc: 0.3289 - val_loss: 1.7298 - val_acc: 0.3820
#
# Epoch 00084: val_loss did not improve from 0.97078
# Epoch 85/100
#  - 33s - loss: 1.8576 - acc: 0.3224 - val_loss: 1.7901 - val_acc: 0.3213
#
# Epoch 00085: val_loss did not improve from 0.97078
# Epoch 86/100
#  - 34s - loss: 1.8566 - acc: 0.3226 - val_loss: 1.6392 - val_acc: 0.3956
#
# Epoch 00086: val_loss did not improve from 0.97078
# Epoch 87/100
#  - 34s - loss: 1.8478 - acc: 0.3241 - val_loss: 1.6709 - val_acc: 0.3744
#
# Epoch 00087: val_loss did not improve from 0.97078
# Epoch 88/100
#  - 62s - loss: 1.8619 - acc: 0.3181 - val_loss: 1.7759 - val_acc: 0.3580
#
# Epoch 00088: val_loss did not improve from 0.97078
# Epoch 89/100
#  - 63s - loss: 1.8632 - acc: 0.3164 - val_loss: 1.6587 - val_acc: 0.3836
#
# Epoch 00089: val_loss did not improve from 0.97078
# Epoch 90/100
#  - 62s - loss: 1.8653 - acc: 0.3159 - val_loss: 1.6340 - val_acc: 0.3792
#
# Epoch 00090: val_loss did not improve from 0.97078
# Epoch 91/100
#  - 63s - loss: 1.8488 - acc: 0.3214 - val_loss: 1.6905 - val_acc: 0.3948
#
# Epoch 00091: val_loss did not improve from 0.97078
# Epoch 92/100
#  - 62s - loss: 1.8658 - acc: 0.3143 - val_loss: 1.7114 - val_acc: 0.3492
#
# Epoch 00092: val_loss did not improve from 0.97078
# Epoch 93/100
#  - 62s - loss: 1.8530 - acc: 0.3169 - val_loss: 1.6636 - val_acc: 0.3972
#
# Epoch 00093: val_loss did not improve from 0.97078
# Epoch 94/100
#  - 63s - loss: 1.8412 - acc: 0.3215 - val_loss: 1.8156 - val_acc: 0.3397
#
# Epoch 00094: val_loss did not improve from 0.97078
# Epoch 95/100
#  - 63s - loss: 1.8498 - acc: 0.3169 - val_loss: 2.0565 - val_acc: 0.2821
#
# Epoch 00095: val_loss did not improve from 0.97078
# Epoch 96/100
#  - 61s - loss: 1.8493 - acc: 0.3231 - val_loss: 1.7699 - val_acc: 0.3397
#
# Epoch 00096: val_loss did not improve from 0.97078
# Epoch 97/100
#  - 62s - loss: 1.8469 - acc: 0.3224 - val_loss: 1.6990 - val_acc: 0.3692
#
# Epoch 00097: val_loss did not improve from 0.97078
# Epoch 98/100
#  - 63s - loss: 1.8473 - acc: 0.3192 - val_loss: 1.7116 - val_acc: 0.3640
#
# Epoch 00098: val_loss did not improve from 0.97078
# Epoch 99/100
#  - 63s - loss: 1.8539 - acc: 0.3189 - val_loss: 1.6903 - val_acc: 0.3750
#
# Epoch 00099: val_loss did not improve from 0.97078
# Epoch 100/100
#  - 62s - loss: 1.8538 - acc: 0.3177 - val_loss: 1.7593 - val_acc: 0.3421
#
# Epoch 00100: val_loss did not improve from 0.97078

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6627

# %%
import datetime
print("Last run on "+datetime.datetime.now().strftime("%d-%b-%Y %H:%M"))
# Out:
# Last run on 11-Jun-2018 18:06

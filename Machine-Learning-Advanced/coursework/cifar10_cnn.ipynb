# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 62s - loss: 1.6162 - acc: 0.4147 - val_loss: 1.3814 - val_acc: 0.4910
#
# Epoch 00001: val_loss improved from inf to 1.38143, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 61s - loss: 1.3073 - acc: 0.5317 - val_loss: 1.1957 - val_acc: 0.5672
#
# Epoch 00002: val_loss improved from 1.38143 to 1.19566, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 61s - loss: 1.1895 - acc: 0.5790 - val_loss: 1.3267 - val_acc: 0.5430
#
# Epoch 00003: val_loss did not improve from 1.19566
# Epoch 4/100
#  - 61s - loss: 1.1159 - acc: 0.6069 - val_loss: 1.0736 - val_acc: 0.6158
#
# Epoch 00004: val_loss improved from 1.19566 to 1.07358, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 61s - loss: 1.0745 - acc: 0.6277 - val_loss: 1.2028 - val_acc: 0.6006
#
# Epoch 00005: val_loss did not improve from 1.07358
# Epoch 6/100
#  - 61s - loss: 1.0512 - acc: 0.6366 - val_loss: 0.9973 - val_acc: 0.6600
#
# Epoch 00006: val_loss improved from 1.07358 to 0.99732, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 62s - loss: 1.0353 - acc: 0.6444 - val_loss: 1.1315 - val_acc: 0.6084
#
# Epoch 00007: val_loss did not improve from 0.99732
# Epoch 8/100
#  - 61s - loss: 1.0314 - acc: 0.6444 - val_loss: 0.9458 - val_acc: 0.6788
#
# Epoch 00008: val_loss improved from 0.99732 to 0.94584, saving model to model.weights.best.hdf5
# Epoch 9/100
#  - 59s - loss: 1.0343 - acc: 0.6482 - val_loss: 0.9831 - val_acc: 0.6724
#
# Epoch 00009: val_loss did not improve from 0.94584
# Epoch 10/100
#  - 60s - loss: 1.0439 - acc: 0.6487 - val_loss: 0.9793 - val_acc: 0.6676
#
# Epoch 00010: val_loss did not improve from 0.94584
# Epoch 11/100
#  - 60s - loss: 1.0517 - acc: 0.6466 - val_loss: 0.9926 - val_acc: 0.6578
#
# Epoch 00011: val_loss did not improve from 0.94584
# Epoch 12/100
#  - 61s - loss: 1.0625 - acc: 0.6440 - val_loss: 1.2161 - val_acc: 0.6158
#
# Epoch 00012: val_loss did not improve from 0.94584
# Epoch 13/100
#  - 61s - loss: 1.0805 - acc: 0.6400 - val_loss: 0.9905 - val_acc: 0.6720
#
# Epoch 00013: val_loss did not improve from 0.94584
# Epoch 14/100
#  - 50s - loss: 1.0861 - acc: 0.6385 - val_loss: 1.0382 - val_acc: 0.6590
#
# Epoch 00014: val_loss did not improve from 0.94584
# Epoch 15/100
#  - 45s - loss: 1.0996 - acc: 0.6352 - val_loss: 1.2795 - val_acc: 0.5826
#
# Epoch 00015: val_loss did not improve from 0.94584
# Epoch 16/100
#  - 46s - loss: 1.1167 - acc: 0.6279 - val_loss: 1.0612 - val_acc: 0.6516
#
# Epoch 00016: val_loss did not improve from 0.94584
# Epoch 17/100
#  - 45s - loss: 1.1371 - acc: 0.6238 - val_loss: 1.2244 - val_acc: 0.6374
#
# Epoch 00017: val_loss did not improve from 0.94584
# Epoch 18/100
#  - 44s - loss: 1.1497 - acc: 0.6182 - val_loss: 1.0072 - val_acc: 0.6658
#
# Epoch 00018: val_loss did not improve from 0.94584
# Epoch 19/100
#  - 44s - loss: 1.1636 - acc: 0.6157 - val_loss: 1.1322 - val_acc: 0.6332
#
# Epoch 00019: val_loss did not improve from 0.94584
# Epoch 20/100
#  - 45s - loss: 1.1829 - acc: 0.6098 - val_loss: 1.1517 - val_acc: 0.6080
#
# Epoch 00020: val_loss did not improve from 0.94584
# Epoch 21/100
#  - 44s - loss: 1.2016 - acc: 0.6041 - val_loss: 1.1191 - val_acc: 0.6384
#
# Epoch 00021: val_loss did not improve from 0.94584
# Epoch 22/100
#  - 45s - loss: 1.2237 - acc: 0.5989 - val_loss: 1.2777 - val_acc: 0.5712
#
# Epoch 00022: val_loss did not improve from 0.94584
# Epoch 23/100
#  - 46s - loss: 1.2585 - acc: 0.5902 - val_loss: 2.7520 - val_acc: 0.3756
#
# Epoch 00023: val_loss did not improve from 0.94584
# Epoch 24/100
#  - 46s - loss: 1.2606 - acc: 0.5854 - val_loss: 1.1785 - val_acc: 0.6116
#
# Epoch 00024: val_loss did not improve from 0.94584
# Epoch 25/100
#  - 46s - loss: 1.2758 - acc: 0.5819 - val_loss: 1.1785 - val_acc: 0.6596
#
# Epoch 00025: val_loss did not improve from 0.94584
# Epoch 26/100
#  - 45s - loss: 1.3018 - acc: 0.5723 - val_loss: 1.0705 - val_acc: 0.6430
#
# Epoch 00026: val_loss did not improve from 0.94584
# Epoch 27/100
#  - 46s - loss: 1.3063 - acc: 0.5716 - val_loss: 1.1915 - val_acc: 0.5918
#
# Epoch 00027: val_loss did not improve from 0.94584
# Epoch 28/100
#  - 45s - loss: 1.3178 - acc: 0.5643 - val_loss: 1.0617 - val_acc: 0.6310
#
# Epoch 00028: val_loss did not improve from 0.94584
# Epoch 29/100
#  - 45s - loss: 1.3424 - acc: 0.5599 - val_loss: 1.6609 - val_acc: 0.5222
#
# Epoch 00029: val_loss did not improve from 0.94584
# Epoch 30/100
#  - 46s - loss: 1.3662 - acc: 0.5492 - val_loss: 1.1518 - val_acc: 0.6222
#
# Epoch 00030: val_loss did not improve from 0.94584
# Epoch 31/100
#  - 46s - loss: 1.3872 - acc: 0.5394 - val_loss: 1.7117 - val_acc: 0.4702
#
# Epoch 00031: val_loss did not improve from 0.94584
# Epoch 32/100
#  - 45s - loss: 1.3946 - acc: 0.5432 - val_loss: 1.0693 - val_acc: 0.6382
#
# Epoch 00032: val_loss did not improve from 0.94584
# Epoch 33/100
#  - 29s - loss: 1.3966 - acc: 0.5409 - val_loss: 1.3722 - val_acc: 0.5728
#
# Epoch 00033: val_loss did not improve from 0.94584
# Epoch 34/100
#  - 30s - loss: 1.4117 - acc: 0.5340 - val_loss: 2.4025 - val_acc: 0.4120
#
# Epoch 00034: val_loss did not improve from 0.94584
# Epoch 35/100
#  - 29s - loss: 1.4098 - acc: 0.5320 - val_loss: 1.3023 - val_acc: 0.5452
#
# Epoch 00035: val_loss did not improve from 0.94584
# Epoch 36/100
#  - 29s - loss: 1.4262 - acc: 0.5274 - val_loss: 2.4915 - val_acc: 0.3948
#
# Epoch 00036: val_loss did not improve from 0.94584
# Epoch 37/100
#  - 29s - loss: 1.4382 - acc: 0.5277 - val_loss: 1.7099 - val_acc: 0.4918
#
# Epoch 00037: val_loss did not improve from 0.94584
# Epoch 38/100
#  - 29s - loss: 1.4430 - acc: 0.5169 - val_loss: 1.2078 - val_acc: 0.6004
#
# Epoch 00038: val_loss did not improve from 0.94584
# Epoch 39/100
#  - 29s - loss: 1.4805 - acc: 0.5074 - val_loss: 1.2283 - val_acc: 0.6008
#
# Epoch 00039: val_loss did not improve from 0.94584
# Epoch 40/100
#  - 29s - loss: 1.4859 - acc: 0.5045 - val_loss: 2.5815 - val_acc: 0.4108
#
# Epoch 00040: val_loss did not improve from 0.94584
# Epoch 41/100
#  - 29s - loss: 1.4939 - acc: 0.5014 - val_loss: 1.5869 - val_acc: 0.5714
#
# Epoch 00041: val_loss did not improve from 0.94584
# Epoch 42/100
#  - 29s - loss: 1.5197 - acc: 0.4968 - val_loss: 1.2053 - val_acc: 0.5774
#
# Epoch 00042: val_loss did not improve from 0.94584
# Epoch 43/100
#  - 29s - loss: 1.5212 - acc: 0.4905 - val_loss: 1.3777 - val_acc: 0.5272
#
# Epoch 00043: val_loss did not improve from 0.94584
# Epoch 44/100
#  - 29s - loss: 1.5403 - acc: 0.4858 - val_loss: 1.8408 - val_acc: 0.3880
#
# Epoch 00044: val_loss did not improve from 0.94584
# Epoch 45/100
#  - 29s - loss: 1.5559 - acc: 0.4805 - val_loss: 1.3628 - val_acc: 0.5174
#
# Epoch 00045: val_loss did not improve from 0.94584
# Epoch 46/100
#  - 30s - loss: 1.5651 - acc: 0.4784 - val_loss: 1.5563 - val_acc: 0.4458
#
# Epoch 00046: val_loss did not improve from 0.94584
# Epoch 47/100
#  - 29s - loss: 1.5683 - acc: 0.4747 - val_loss: 2.5340 - val_acc: 0.3224
#
# Epoch 00047: val_loss did not improve from 0.94584
# Epoch 48/100
#  - 29s - loss: 1.5753 - acc: 0.4724 - val_loss: 2.1407 - val_acc: 0.3426
#
# Epoch 00048: val_loss did not improve from 0.94584
# Epoch 49/100
#  - 29s - loss: 1.5918 - acc: 0.4688 - val_loss: 1.4634 - val_acc: 0.5410
#
# Epoch 00049: val_loss did not improve from 0.94584
# Epoch 50/100
#  - 29s - loss: 1.6021 - acc: 0.4641 - val_loss: 2.0278 - val_acc: 0.4484
#
# Epoch 00050: val_loss did not improve from 0.94584
# Epoch 51/100
#  - 29s - loss: 1.6010 - acc: 0.4572 - val_loss: 1.6170 - val_acc: 0.4356
#
# Epoch 00051: val_loss did not improve from 0.94584
# Epoch 52/100
#  - 29s - loss: 1.6113 - acc: 0.4552 - val_loss: 1.5567 - val_acc: 0.4884
#
# Epoch 00052: val_loss did not improve from 0.94584
# Epoch 53/100
#  - 29s - loss: 1.6051 - acc: 0.4558 - val_loss: 1.7595 - val_acc: 0.4124
#
# Epoch 00053: val_loss did not improve from 0.94584
# Epoch 54/100
#  - 29s - loss: 1.6213 - acc: 0.4504 - val_loss: 1.3882 - val_acc: 0.5216
#
# Epoch 00054: val_loss did not improve from 0.94584
# Epoch 55/100
#  - 29s - loss: 1.6350 - acc: 0.4478 - val_loss: 1.7838 - val_acc: 0.3576
#
# Epoch 00055: val_loss did not improve from 0.94584
# Epoch 56/100
#  - 29s - loss: 1.6238 - acc: 0.4543 - val_loss: 1.3454 - val_acc: 0.5368
#
# Epoch 00056: val_loss did not improve from 0.94584
# Epoch 57/100
#  - 29s - loss: 1.6361 - acc: 0.4452 - val_loss: 1.6953 - val_acc: 0.4172
#
# Epoch 00057: val_loss did not improve from 0.94584
# Epoch 58/100
#  - 29s - loss: 1.6245 - acc: 0.4486 - val_loss: 3.2081 - val_acc: 0.3786
# Epoch 00058: val_loss did not improve from 0.94584
# Epoch 59/100
#  - 29s - loss: 1.6376 - acc: 0.4447 - val_loss: 1.6440 - val_acc: 0.5354
#
# Epoch 00059: val_loss did not improve from 0.94584
# Epoch 60/100
#  - 29s - loss: 1.6448 - acc: 0.4423 - val_loss: 2.2843 - val_acc: 0.3402
#
# Epoch 00060: val_loss did not improve from 0.94584
# Epoch 61/100
#  - 29s - loss: 1.6745 - acc: 0.4363 - val_loss: 1.9529 - val_acc: 0.4836
#
# Epoch 00061: val_loss did not improve from 0.94584
# Epoch 62/100
#  - 29s - loss: 1.6781 - acc: 0.4337 - val_loss: 1.4944 - val_acc: 0.4968
#
# Epoch 00062: val_loss did not improve from 0.94584
# Epoch 63/100
#  - 29s - loss: 1.6698 - acc: 0.4337 - val_loss: 1.5943 - val_acc: 0.4406
#
# Epoch 00063: val_loss did not improve from 0.94584
# Epoch 64/100
#  - 29s - loss: 1.6865 - acc: 0.4302 - val_loss: 1.6572 - val_acc: 0.4312
#
# Epoch 00064: val_loss did not improve from 0.94584
# Epoch 65/100
#  - 29s - loss: 1.6689 - acc: 0.4341 - val_loss: 1.6971 - val_acc: 0.3882
#
# Epoch 00065: val_loss did not improve from 0.94584
# Epoch 66/100
#  - 29s - loss: 1.6761 - acc: 0.4297 - val_loss: 1.3734 - val_acc: 0.5108
#
# Epoch 00066: val_loss did not improve from 0.94584
# Epoch 67/100
#  - 29s - loss: 1.6845 - acc: 0.4271 - val_loss: 1.5886 - val_acc: 0.4634
#
# Epoch 00067: val_loss did not improve from 0.94584
# Epoch 68/100
#  - 29s - loss: 1.7078 - acc: 0.4207 - val_loss: 1.5624 - val_acc: 0.4488
#
# Epoch 00068: val_loss did not improve from 0.94584
# Epoch 69/100
#  - 29s - loss: 1.6864 - acc: 0.4237 - val_loss: 1.3961 - val_acc: 0.5102
#
# Epoch 00069: val_loss did not improve from 0.94584
# Epoch 70/100
#  - 29s - loss: 1.6973 - acc: 0.4266 - val_loss: 1.4845 - val_acc: 0.5072
#
# Epoch 00070: val_loss did not improve from 0.94584
# Epoch 71/100
#  - 29s - loss: 1.6949 - acc: 0.4186 - val_loss: 1.4030 - val_acc: 0.4764
#
# Epoch 00071: val_loss did not improve from 0.94584
# Epoch 72/100
#  - 29s - loss: 1.6875 - acc: 0.4251 - val_loss: 2.4033 - val_acc: 0.4380
#
# Epoch 00072: val_loss did not improve from 0.94584
# Epoch 73/100
#  - 29s - loss: 1.6943 - acc: 0.4163 - val_loss: 1.9973 - val_acc: 0.4478
#
# Epoch 00073: val_loss did not improve from 0.94584
# Epoch 74/100
#  - 29s - loss: 1.7021 - acc: 0.4155 - val_loss: 3.8993 - val_acc: 0.2808
#
# Epoch 00074: val_loss did not improve from 0.94584
# Epoch 75/100
#  - 29s - loss: 1.7177 - acc: 0.4132 - val_loss: 2.1563 - val_acc: 0.4048
#
# Epoch 00075: val_loss did not improve from 0.94584
# Epoch 76/100
#  - 29s - loss: 1.7242 - acc: 0.4107 - val_loss: 1.4751 - val_acc: 0.5082
#
# Epoch 00076: val_loss did not improve from 0.94584
# Epoch 77/100
#  - 29s - loss: 1.6950 - acc: 0.4136 - val_loss: 2.3060 - val_acc: 0.4096
#
# Epoch 00077: val_loss did not improve from 0.94584
# Epoch 78/100
#  - 29s - loss: 1.7124 - acc: 0.4119 - val_loss: 1.4372 - val_acc: 0.4982
#
# Epoch 00078: val_loss did not improve from 0.94584
# Epoch 79/100
#  - 29s - loss: 1.7076 - acc: 0.4156 - val_loss: 1.5776 - val_acc: 0.5008
#
# Epoch 00079: val_loss did not improve from 0.94584
# Epoch 80/100
#  - 29s - loss: 1.7296 - acc: 0.4064 - val_loss: 1.6715 - val_acc: 0.4300
#
# Epoch 00080: val_loss did not improve from 0.94584
# Epoch 81/100
#  - 29s - loss: 1.7416 - acc: 0.4014 - val_loss: 1.8427 - val_acc: 0.3614
#
# Epoch 00081: val_loss did not improve from 0.94584
# Epoch 82/100
#  - 29s - loss: 1.7371 - acc: 0.4018 - val_loss: 1.6011 - val_acc: 0.4346
#
# Epoch 00082: val_loss did not improve from 0.94584
# Epoch 83/100
#  - 29s - loss: 1.7524 - acc: 0.3939 - val_loss: 1.4052 - val_acc: 0.5348
#
# Epoch 00083: val_loss did not improve from 0.94584
# Epoch 84/100
#  - 29s - loss: 1.7648 - acc: 0.3931 - val_loss: 1.6482 - val_acc: 0.4364
#
# Epoch 00084: val_loss did not improve from 0.94584
# Epoch 85/100
#  - 29s - loss: 1.7665 - acc: 0.3908 - val_loss: 1.9053 - val_acc: 0.3626
#
# Epoch 00085: val_loss did not improve from 0.94584
# Epoch 86/100
#  - 29s - loss: 1.7797 - acc: 0.3864 - val_loss: 1.5239 - val_acc: 0.4632
#
# Epoch 00086: val_loss did not improve from 0.94584
# Epoch 87/100
#  - 29s - loss: 1.7607 - acc: 0.3923 - val_loss: 1.5532 - val_acc: 0.4316
#
# Epoch 00087: val_loss did not improve from 0.94584
# Epoch 88/100
#  - 29s - loss: 1.7640 - acc: 0.3930 - val_loss: 2.0926 - val_acc: 0.3906
#
# Epoch 00088: val_loss did not improve from 0.94584
# Epoch 89/100
#  - 29s - loss: 1.7765 - acc: 0.3859 - val_loss: 1.6611 - val_acc: 0.4450
#
# Epoch 00089: val_loss did not improve from 0.94584
# Epoch 90/100
#  - 30s - loss: 1.7788 - acc: 0.3790 - val_loss: 1.5185 - val_acc: 0.4308
#
# Epoch 00090: val_loss did not improve from 0.94584
# Epoch 91/100
#  - 29s - loss: 1.7800 - acc: 0.3828 - val_loss: 1.7009 - val_acc: 0.3972
#
# Epoch 00091: val_loss did not improve from 0.94584
# Epoch 92/100
#  - 29s - loss: 1.7920 - acc: 0.3768 - val_loss: 1.7223 - val_acc: 0.4354
#
# Epoch 00092: val_loss did not improve from 0.94584
# Epoch 93/100
#  - 29s - loss: 1.7932 - acc: 0.3748 - val_loss: 1.5677 - val_acc: 0.4502
#
# Epoch 00093: val_loss did not improve from 0.94584
# Epoch 94/100
#  - 30s - loss: 1.8255 - acc: 0.3675 - val_loss: 1.9400 - val_acc: 0.3662
#
# Epoch 00094: val_loss did not improve from 0.94584
# Epoch 95/100
#  - 29s - loss: 1.8276 - acc: 0.3677 - val_loss: 1.6932 - val_acc: 0.3748
#
# Epoch 00095: val_loss did not improve from 0.94584
# Epoch 96/100
#  - 30s - loss: 1.8237 - acc: 0.3721 - val_loss: 1.7653 - val_acc: 0.3874
#
# Epoch 00096: val_loss did not improve from 0.94584
# Epoch 97/100
#  - 30s - loss: 1.8146 - acc: 0.3661 - val_loss: 1.9174 - val_acc: 0.3984
#
# Epoch 00097: val_loss did not improve from 0.94584
# Epoch 98/100
#  - 29s - loss: 1.8128 - acc: 0.3652 - val_loss: 1.5996 - val_acc: 0.4112
#
# Epoch 00098: val_loss did not improve from 0.94584
# Epoch 99/100
#  - 29s - loss: 1.8285 - acc: 0.3580 - val_loss: 1.5854 - val_acc: 0.4128
#
# Epoch 00099: val_loss did not improve from 0.94584
# Epoch 100/100
#  - 29s - loss: 1.8126 - acc: 0.3638 - val_loss: 1.6059 - val_acc: 0.4300
#
# Epoch 00100: val_loss did not improve from 0.94584

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6676

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %%
import datetime
print("Last run on "+datetime.datetime.now().strftime("%d-%b-%Y %H:%M"))
# Out:
# Last run on 11-Jun-2018 18:53

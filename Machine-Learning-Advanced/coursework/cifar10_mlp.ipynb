# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train an MLP to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten

# define the model
model = Sequential()
model.add(Flatten(input_shape = x_train.shape[1:]))
model.add(Dense(1000, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              3073000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,590,642
# Trainable params: 3,590,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='MLP.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 91s - loss: 2.0951 - acc: 0.2740 - val_loss: 1.8519 - val_acc: 0.3152
#
# Epoch 00001: val_loss improved from inf to 1.85189, saving model to MLP.weights.best.hdf5
# Epoch 2/20
#  - 91s - loss: 1.8406 - acc: 0.3370 - val_loss: 1.8967 - val_acc: 0.3268
#
# Epoch 00002: val_loss did not improve from 1.85189
# Epoch 3/20
#  - 91s - loss: 1.7980 - acc: 0.3549 - val_loss: 1.7362 - val_acc: 0.3654
#
# Epoch 00003: val_loss improved from 1.85189 to 1.73618, saving model to MLP.weights.best.hdf5
# Epoch 4/20
#  - 89s - loss: 1.7771 - acc: 0.3618 - val_loss: 1.7771 - val_acc: 0.3670
#
# Epoch 00004: val_loss did not improve from 1.73618
# Epoch 5/20
#  - 91s - loss: 1.7650 - acc: 0.3694 - val_loss: 1.6992 - val_acc: 0.3936
#
# Epoch 00005: val_loss improved from 1.73618 to 1.69920, saving model to MLP.weights.best.hdf5
# Epoch 6/20
#  - 89s - loss: 1.7574 - acc: 0.3718 - val_loss: 1.6988 - val_acc: 0.3970
#
# Epoch 00006: val_loss improved from 1.69920 to 1.69879, saving model to MLP.weights.best.hdf5
# Epoch 7/20
#  - 87s - loss: 1.7545 - acc: 0.3762 - val_loss: 1.6964 - val_acc: 0.3820
#
# Epoch 00007: val_loss improved from 1.69879 to 1.69636, saving model to MLP.weights.best.hdf5
# Epoch 8/20
#  - 91s - loss: 1.7517 - acc: 0.3834 - val_loss: 1.6769 - val_acc: 0.3986
#
# Epoch 00008: val_loss improved from 1.69636 to 1.67690, saving model to MLP.weights.best.hdf5
# Epoch 9/20
#  - 91s - loss: 1.7518 - acc: 0.3840 - val_loss: 1.7399 - val_acc: 0.3498
#
# Epoch 00009: val_loss did not improve from 1.67690
# Epoch 10/20
#  - 78s - loss: 1.7526 - acc: 0.3807 - val_loss: 1.6844 - val_acc: 0.4086
#
# Epoch 00010: val_loss did not improve from 1.67690
# Epoch 11/20
#  - 77s - loss: 1.7476 - acc: 0.3810 - val_loss: 1.7128 - val_acc: 0.3938
#
# Epoch 00011: val_loss did not improve from 1.67690
# Epoch 12/20
#  - 75s - loss: 1.7558 - acc: 0.3833 - val_loss: 1.7358 - val_acc: 0.3788
#
# Epoch 00012: val_loss did not improve from 1.67690
# Epoch 13/20
#  - 76s - loss: 1.7590 - acc: 0.3783 - val_loss: 1.6932 - val_acc: 0.3966
#
# Epoch 00013: val_loss did not improve from 1.67690
# Epoch 14/20
#  - 76s - loss: 1.7573 - acc: 0.3813 - val_loss: 1.6954 - val_acc: 0.4036
#
# Epoch 00014: val_loss did not improve from 1.67690
# Epoch 15/20
#  - 77s - loss: 1.7592 - acc: 0.3840 - val_loss: 1.7607 - val_acc: 0.3680
#
# Epoch 00015: val_loss did not improve from 1.67690
# Epoch 16/20
#  - 77s - loss: 1.7701 - acc: 0.3791 - val_loss: 1.7084 - val_acc: 0.3756
#
# Epoch 00016: val_loss did not improve from 1.67690
# Epoch 17/20
#  - 77s - loss: 1.7660 - acc: 0.3806 - val_loss: 1.7082 - val_acc: 0.3736
#
# Epoch 00017: val_loss did not improve from 1.67690
# Epoch 18/20
#  - 75s - loss: 1.7681 - acc: 0.3789 - val_loss: 1.7224 - val_acc: 0.4064
#
# Epoch 00018: val_loss did not improve from 1.67690
# Epoch 19/20
#  - 78s - loss: 1.7721 - acc: 0.3782 - val_loss: 1.8179 - val_acc: 0.3516
#
# Epoch 00019: val_loss did not improve from 1.67690
# Epoch 20/20
#  - 77s - loss: 1.7768 - acc: 0.3793 - val_loss: 1.7435 - val_acc: 0.3896
#
# Epoch 00020: val_loss did not improve from 1.67690

# %% [markdown]
# ### 8. Load the Model with the Best Classification Accuracy on the Validation Set

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('MLP.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.407

# %%
import datetime
print("Last run on "+datetime.datetime.now().strftime("%d-%b-%Y %H:%M"))
# Out:
# Last run on 11-Jun-2018 18:20
